# %% [markdown]
# <a href="https://colab.research.google.com/github/inforeqd512/QLearning/blob/main/Tribe_Q_learning_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import math
import copy #for deepcopy()
from enum import Enum
# !python -V
# Out:
# Python 3.7.11

# %%
class Business_Rules:

  def __init__(self):
    self.target_dr_per_lead = 5
    self.actions = ['reassign', 'promote_dr', 'hire']
    self.ceil_total_leaders_leading = 10
    self.ceil_total_people_in_grade = 50
    self.grade_hierarchy = ["3", "4.1", "4.2", "4.3", "4.4", "5.1", "5.2", "MS"]
    self.leaders_can_only_be_perms = True
    self.perm_grades = ["3", "4.1", "4.2", "4.3", "4.4", "5.1", "5.2"]
    self.chapter_leads_4_point_2_and_above = True
    self.drs_must_be_grades_lower_than_lead = True

  def print_info(self):
    print("Business Rules")
    print(self.target_dr_per_lead)
    print(self.actions)
    print(self.grade_hierarchy)
    print(self.perm_grades)

# %%
class Chapter_Stats:
  def __init__(self, 
               chapter, 
               allocated_leaders = {"3":3},
               people_gradewise = {"3":0, "4.1":0, "4.2":0, "4.3":0, "4.4":0, "5.1":0, "5.2":0, "MS":0},
               business_rules = Business_Rules()):
    self.chapter = chapter
    self.allocated_leaders = allocated_leaders
    self.people_gradewise = people_gradewise
    self.business_rules = business_rules

  def grade_hierarchy(self):
    return self.business_rules.grade_hierarchy

  def total_people_in_grade(self, grade):
    return self.people_gradewise[grade]

  def all_leader_grades_utilised(self):
    is_all_leader_grades_utilised = True
    for grade in self.business_rules.perm_grades:
      num_unallocated_leaders = self.unallocated_leaders(grade)
      if num_unallocated_leaders > 0:
        is_all_leader_grades_utilised = False
        break

  def unallocated_leaders(self, grade):
    if grade in self.people_gradewise:
      total_leaders = self.people_gradewise[grade] 
      num_allocated_leaders = self.num_leads(grade)
      num_unallocated_leaders = total_leaders - num_allocated_leaders
      return num_unallocated_leaders
    else:
      return None

  def leads_uptill_grade(self, grade):
    num_leads_uptill_grade = 0 
    for perm_grade in self.grade_hierarchy():
      num_leads_uptill_grade += self.num_leads(perm_grade)
      if perm_grade == grade:
        break

    return num_leads_uptill_grade

  def num_leads(self, grade):
    if grade in self.allocated_leaders:
      return self.allocated_leaders[grade]
    else:
      return 0

  def list_drs(self, grade):
    all_lower_perm_grades = []

    start = False
    for perm_grade in self.grade_hierarchy():
      if start == True: #put this in start of loop so that the grade being searched is skipped
        all_lower_perm_grades.append(perm_grade)

      if perm_grade == grade:
        start = True

    return all_lower_perm_grades

  def num_drs(self, grade):
    num_people = 0
    for dr in self.list_drs(grade):
      num_people += self.total_people_in_grade(dr)
    return num_people

  def dr_per_lead_for_grade(self, grade):
    total_dr_per_lead = 0
    num_drs = self.num_drs(grade)
    num_leads_uptill_grade = self.leads_uptill_grade(grade)
    num_people_in_grade = self.total_people_in_grade(grade)
    if self.grade_hierarchy()[0]:
      highest_grade_with_no_boss = self.grade_hierarchy()[0]

    if num_leads_uptill_grade == 0:
      return total_dr_per_lead

    for perm_grade in self.grade_hierarchy():
      if perm_grade == grade: 
        dr_per_lead_for_grade = num_drs / num_leads_uptill_grade
        total_dr_per_lead += dr_per_lead_for_grade
        print("grade == : ", perm_grade, " : ", dr_per_lead_for_grade, "total : ",total_dr_per_lead)
        dr_per_lead_for_grade_people_led_by_higher_grades = num_people_in_grade / num_leads_uptill_grade
        total_dr_per_lead += dr_per_lead_for_grade_people_led_by_higher_grades
        print("grade == : ", perm_grade, " : ", dr_per_lead_for_grade_people_led_by_higher_grades, "total : ",total_dr_per_lead)
        break #stop when the perm grade is same as the grade
      
      if perm_grade == highest_grade_with_no_boss:
        #ignore
        pass
      else:
        num_total_people_in_grade = self.total_people_in_grade(perm_grade)
        dr_per_lead_for_grade = num_total_people_in_grade / num_leads_uptill_grade
        total_dr_per_lead += dr_per_lead_for_grade
        print(perm_grade, ":", dr_per_lead_for_grade, "total",total_dr_per_lead)

    return total_dr_per_lead

  def drs_per_lead(self):
    #get the list of allocated leads by increasing order of grade_hierarchy
    max_grade_of_allocated_leader = None
    dict_allocated_leaders_ordered_by_grade = {}
    for grade in self.grade_hierarchy():
      if grade in self.allocated_leaders:
        dict_allocated_leaders_ordered_by_grade[grade] = self.allocated_leaders[grade]
        max_grade_of_allocated_leader = grade
      else:
        dict_allocated_leaders_ordered_by_grade[grade] = 0

    print("drs_per_lead **** :", dict_allocated_leaders_ordered_by_grade)
    print("max_grade_of_allocated_leader **** :", max_grade_of_allocated_leader)

    num_dr_per_lead = None
    if max_grade_of_allocated_leader != None:
      num_dr_per_lead = self.dr_per_lead_for_grade(max_grade_of_allocated_leader)
      print("num_dr_per_lead **** :", num_dr_per_lead)

    return num_dr_per_lead


  def print_info(self):
    print("Chapter_Stats_v2")
    print("chapter :", self.chapter)
    print("allocated_leaders :", self.allocated_leaders)
    print("people_gradewise :", self.people_gradewise)
    print("drs_per_lead : ", self.drs_per_lead())

  def chapter_stats_values_for_hashing(self):
    hash_value = (self.chapter, tuple(self.allocated_leaders.items()), tuple(self.people_gradewise.items()))
    return hash_value
      
  def assign_lead(self):
    for grade in self.people_gradewise: #todo, relook at functions as this should be ordered according to the business rules grade_hierarchy
      if self.unallocated_leaders(grade) > 0:
        if grade in self.allocated_leaders:
          num_allocated_leaders = self.allocated_leaders[grade]
          num_allocated_leaders += 1
          self.allocated_leaders[grade] = num_allocated_leaders
          print("assign_lead :", grade,  num_allocated_leaders)
          break
        else:
          self.allocated_leaders[grade] = 1
          print("assign_lead :", grade,  1)
          break

# %%
class State:

    def __init__(self, chapter_stats, business_rules):
      self.chapter_stats = chapter_stats
      self.business_rules = business_rules

    def print_info(self):
      self.chapter_stats.print_info()
      self.business_rules.print_info()

    def state_hash(self):
      hash_value = hash(self.chapter_stats.chapter_stats_values_for_hashing())
      return hash_value

    def state_copy(self):
      new_state = copy.deepcopy(self)
      return new_state
    
    def drs_per_lead(self):
      return self.chapter_stats.drs_per_lead()

    def target_dr_per_lead(self):
      return self.business_rules.target_dr_per_lead

    def all_leader_grades_utilised(self):
      return self.chapter_stats.all_leader_grades_utilised()
    
    def assign_lead(self):
      self.chapter_stats.assign_lead()

# %%
class ActionList:

    def __init__(self, action_strings):
      self.actions=[]
      self.list_action_hash=[]
      for action in action_strings:
        ac = Action(action)
        self.actions.append(ac)
        self.list_action_hash.append(ac.action_hash)

# %%
class Action:

  def __init__(self, action_string):
    self.action = action_string
    self.action_hash = hash(action_string)
    return

  def perform_action(self, state):
    if self.action == "reassign":
      return Reassign.run(state)
    elif self.action == "promote_dr":
      return Promote_DR.run(state)
    elif self.action == "hire":
      return Hire.run(state)

  def print_info(self):
    print(self.action, self.action_hash)

# %%
class Reassign:

  def __init__(self):
    #do nothing now
    return

  @classmethod
  def run(self, state):
    new_state = self.reassigned_leader(state)
    return new_state

  @classmethod
  def reassigned_leader(self, state):
    print("\n\n******reassigned_leader*******")
    new_state = state.state_copy()
    new_state.assign_lead()
    return new_state

# %%
class Promote_DR:
  def __init__(self):
    return

  @classmethod
  def run(self, state):
    new_state = state #do nothing for now so return the same state
    return new_state

# %%
class Hire:
  def __init__(self):
    return

  @classmethod
  def run(self, state):
    new_state = state #do nothing for now so return the same state
    return new_state

# %%
class Q_table:
  """
  dict[key(state hash, action hash)] = q-values
  """
  
  def __init__(self):
    self.Q = {}
    return

  def getStateActionHashPairKey(self, state_hash, action_hash):
    """ Returns state-pair hash key, requires separate state and action hash keys first """
    # return state_hash*action_hash
    return str(state_hash)+" "+str(action_hash)

  def getActionHashListForNewState(self, actions):
    list_action_hash = []
    for action in actions:
      list_action_hash.append(action.action_hash)
    return list_action_hash

  def getValueQ(self, state_hash, action_hash):
    """ Get expected reward given an action in a given state,
        returns 0 if the state-action pair has not been seen before.
        Input is state and action hash key                          """

    state_action_key = self.getStateActionHashPairKey(state_hash, action_hash)
    if state_action_key in self.Q:
        return self.Q.get(state_action_key)
    else:
        self.Q[state_action_key] = 0
        return 0

  def setValueQ(self, state_hash, action_hash, value):
    """ Set value in Q """
    state_action_key = self.getStateActionHashPairKey(state_hash, action_hash)
    self.Q[state_action_key] = value

  def getBestAction(self, state_hash, list_action_hash, list_actions):
    """ Get best action given a set of possible actions in a given state """

    best_action = list_actions[0]

    # Find action that given largest Q in given state
    maxQ = 0
    for a_hash, action in zip(list_action_hash, list_actions):
        tmpQ = self.getValueQ(state_hash, a_hash)
        if maxQ < tmpQ:
          maxQ = tmpQ
          best_action = action

    return best_action

  def getMaxQ(self, state_hash, list_action_hash):
      """ Returns the maximum Q value given a state and list of actions (input is hash keys) """
      maxQ = 0
      for a_hash in list_action_hash:
          tmpQ = self.getValueQ(state_hash, a_hash) 
          if maxQ < tmpQ:
              maxQ = tmpQ
      return maxQ


  def updateQ(self, old_state, action_to_perform, reward, new_state, next_possible_actions, discount_factor, learning_rate):
    """ Implements Q-learning iterative algorithm """

    state_hash = old_state.state_hash()
    action_hash = action_to_perform.action_hash

    # Get current Q Value
    old_q_value = self.getValueQ(state_hash, action_hash)

    # Find max Q value given the possible set of actions in the next state
    list_action_hash = self.getActionHashListForNewState(next_possible_actions)
    max_nextQ = self.getMaxQ(new_state.state_hash(), list_action_hash) 
    
    temporal_difference = reward + (discount_factor * max_nextQ) - old_q_value

    #update the Q-value for the previous state and action pair
    new_q_value = old_q_value + (learning_rate * temporal_difference)
    self.setValueQ(state_hash, action_hash, new_q_value)
    # print("updateQ", state_hash, action_hash, new_q_value)

  def print_info(self):
    print("\n\nQ_table")
    print(self.Q)

# %%
class Reward:
  def __init__(self):
    return
  
  def reward_function(self, old_state, action_to_perform):
    """ 
    Returns positive value if actions gets closer to target state and values are the size of step closer to the target, 
    Returns -ve value if action take away from target
    """
    new_state = action_to_perform.perform_action(old_state)

    if new_state.all_leader_grades_utilised():
      reward = -100 #possible promotion scenario
      print("*****1st cond*****", new_state.all_leader_grades_utilised())
      return reward
    
    if new_state.drs_per_lead() == 0:
      reward = -100
    elif new_state.drs_per_lead() > 0 and new_state.drs_per_lead() <= new_state.target_dr_per_lead():
      print("*****2nd cond*****", new_state.drs_per_lead(), "****", new_state.target_dr_per_lead())
      reward = 100
    else:
      reward = old_state.drs_per_lead() - new_state.drs_per_lead()

    return reward

# %%
class Environment:

  def __init__(self):
    self.business_rules = Business_Rules()
    self.action_list = ActionList(self.business_rules.actions)
    self.reward = Reward()

  def possible_actions_in_state(self, state):
    return self.action_list.actions

  def hasReachedTerminalState(self, reward):
    if reward == 100 or reward == -100:
      return True
    else:
      return False

# %%
class Episode:

  preconditioned_episodes = [
            {"chapter": "Analyst", 
             "allocated_leaders": {"3":0, "4.1":1}, \
             "people_gradewise" : {"3":0, "4.1":1, "4.2":6, "4.3":6, "4.4":1, "5.1":0, "5.2":2, "MS":7} },
            {"chapter": "ios", 
             "allocated_leaders": {"3":0, "4.1":0, "4.2":1}, \
             "people_gradewise" : {"3":0, "4.1":0, "4.2":5, "4.3":6, "4.4":2, "5.1":0, "5.2":0, "MS":14} },
            {"chapter": "android", \
             "allocated_leaders": {"3":0, "4.1":1}, \
             "people_gradewise" : {"3":0, "4.1":0, "4.2":4, "4.3":4, "4.4":4, "5.1":0, "5.2":0, "MS":9} },
            {"chapter": "be engg", \
             "allocated_leaders": {"3":2.5}, \
             "people_gradewise" : {"3":2.5, "4.1":3, "4.2":4, "4.3":6, "4.4":5, "5.1":1, "5.2":2, "MS":27} },
            {"chapter": "delivery leads", \
             "allocated_leaders": {"3":0, "4.1":1}, \
             "people_gradewise" : {"3":0, "4.1":1, "4.2":3.5, "4.3":0.5, "4.4":0.8, "5.1":0, "5.2":0, "MS":3} },
            {"chapter": "environment", \
             "allocated_leaders": {"3":0, "4.1":0, "4.2":1}, \
             "people_gradewise" : {"3":0, "4.1":0, "4.2":2, "4.3":1, "4.4":1, "5.1":0, "5.2":0, "MS":2} },
            {"chapter": "sre", \
             "allocated_leaders": {"3":1, "4.1":1}, \
             "people_gradewise" : {"3":1, "4.1":1, "4.2":1, "4.3":7, "4.4":4, "5.1":0, "5.2":0, "MS":3} },
            {"chapter": "testing", \
             "allocated_leaders": {"3":0, "4.1":1}, \
             "people_gradewise" : {"3":0, "4.1":0, "4.2":1.5, "4.3":3, "4.4":2, "5.1":1, "5.2":0, "MS":18} },
            {"chapter": "reassign wont work", \
             "allocated_leaders": {"3":2.5, "4.1":1}, \
             "people_gradewise" : {"3":2.5, "4.1":3, "4.2":0, "4.3":0, "4.4":5, "5.1":1, "5.2":2, "MS":27} },
  ]

  def __init__(self, episode_number):
    self.episode_number = episode_number
    self.state = None
    if self.episode_number < len(self.preconditioned_episodes):
      business_rules = Business_Rules()
      dict = self.preconditioned_episodes[self.episode_number]
      print("preconditioned_episode :\n", dict)
      chapter_stats = Chapter_Stats(chapter=dict["chapter"],allocated_leaders=dict["allocated_leaders"],people_gradewise=dict["people_gradewise"],business_rules=business_rules)
      self.state = State(chapter_stats, business_rules)
    else:
      business_rules = Business_Rules()

      people_gradewise={}
      for grade in business_rules.grade_hierarchy:
        people_gradewise[grade] = np.random.randint(business_rules.ceil_total_people_in_grade)

      total_leaders_leading = np.random.randint(0,len(business_rules.perm_grades)-1)
      allocated_leaders={}
      i=0
      for grade in people_gradewise:
        total_people = people_gradewise[grade]
        if total_people > 0:
          allocated_leaders[grade] = np.random.randint(total_people)
        i += 1
        if i > total_leaders_leading:
          break


      chapter_stats = Chapter_Stats(chapter="chapter",allocated_leaders=allocated_leaders,people_gradewise=people_gradewise,business_rules=business_rules)
      print("simulated episode data :")
      chapter_stats.print_info()
      self.state = State(chapter_stats, business_rules)

    return

# %%
class Trainer:

  def __init__(self):
    self.q_table = Q_table()
    self.environment = Environment()

    #define training parameters
    self.epsilon = 0.9 #the percentage of time when we should take the best action (instead of a random action)
    self.discount_factor = 0.9 #discount factor for future rewards
    self.learning_rate = 0.9 #the rate at which the AI agent should learn
    self.num_episodes = 15 #1000

    for action in self.environment.action_list.actions:
      action.print_info()

    return

  
  #define an epsilon greedy algorithm that will choose which action to take next 
  def get_next_action(self, state_hash, list_action_hash, list_actions, epsilon):
    #if a randomly chosen value between 0 and 1 is less than epsilon, 
    #then choose the most promising value from the Q-table for this state.
    if np.random.random() < epsilon:
      best_action = self.q_table.getBestAction(state_hash, list_action_hash, list_actions)
      return best_action
    else: #choose a random action
      random_idx = np.random.choice(len(list_actions))
      random_action = list_actions[random_idx]
      return random_action

  def train(self, should_print):
    #run through 1000 training episodes
    for episode_number in range(self.num_episodes):
      #get the starting state for this episode
      episode = Episode(episode_number)
      print("episode_number : ", episode.episode_number)

      #continue taking actions  until we reach a terminal state
      #(i.e., until we reach the final team structure or hit a bad structure)
      while True:

        #choose which action to take 
        action_to_perform = self.get_next_action(episode.state.state_hash(), \
                                                 self.environment.action_list.list_action_hash, \
                                                 self.environment.action_list.actions, \
                                                 self.epsilon)

        #perform the chosen action, and transition to the next state 
        old_state = episode.state
        new_state = action_to_perform.perform_action(old_state)

        #receive the reward for moving to the new state
        reward = self.environment.reward.reward_function(old_state, action_to_perform)

        if should_print:
          print("*********episode state after reward********  : ")
          episode.state.print_info()        
          print("\n action_to_perform :\n")
          action_to_perform.print_info()
          print("\n new_state :\n")
          new_state.print_info()        
          print("\nreward: \n", reward)

        if self.environment.hasReachedTerminalState(reward):
          episode.state = new_state
          print("breaking... terminal state \n")
          break

        next_possible_actions = self.environment.possible_actions_in_state(new_state)
        self.q_table.updateQ(old_state, action_to_perform, reward, new_state, next_possible_actions, self.discount_factor, self.learning_rate)

        episode.state = new_state

 #Define a function that will get the shortest path between the starting out team structure and the most favorable team structure 
  def get_shortest_path(self, old_state):
    i=0
    shortest_path = []
    shortest_path.append(old_state)
    while True:
      action_to_perform = self.get_next_action(old_state.state_hash(), \
                                               self.environment.action_list.list_action_hash, \
                                               self.environment.action_list.actions, 
                                               1.) #always the best action

      new_state = action_to_perform.perform_action(old_state)
      shortest_path.append(new_state)

      reward = self.environment.reward.reward_function(old_state, action_to_perform)
      print("reward :", reward)
      if self.environment.hasReachedTerminalState(reward):
        episode.state = new_state
        break

      old_state = new_state
    
    for state in shortest_path:
      state.print_info()

# %% [markdown]
# # TESTING

# %% [markdown]
# # Chapter_Stats Testing

# %%
cs_v2 = Chapter_Stats("BE Chapter", 
                         allocated_leaders = {"3":3, "4.1":3, "4.2":4, "4.3":2},
                         people_gradewise = {"3":3, "4.1":3, "4.2":4, "4.3":6, "4.4":5, "5.1":1, "5.2":2, "MS":27}
                         )

# %%
print(cs_v2.drs_per_lead())
# Out:
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 2, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.25 total 0.25
# 4.2 : 0.3333333333333333 total 0.5833333333333333
# grade == :  4.3  :  2.9166666666666665 total :  3.5
# grade == :  4.3  :  0.5 total :  4.0
# num_dr_per_lead **** : 4.0
# 4.0

# %%
print(cs_v2.total_people_in_grade("3"))
print(cs_v2.total_people_in_grade("4.1"))
print(cs_v2.total_people_in_grade("MS"))
# Out:
# 3
# 3
# 27

# %%
print(cs_v2.unallocated_leaders("3"))
print(cs_v2.unallocated_leaders("4.1"))
print(cs_v2.unallocated_leaders("MS"))
# Out:
# 0
# 0
# 27

# %%
print(cs_v2.list_drs("3"))
print(cs_v2.list_drs("4.1"))
print(cs_v2.list_drs("MS"))

print(cs_v2.num_drs("3"))
print(cs_v2.num_drs("4.1"))
print(cs_v2.num_drs("MS"))
# Out:
# ['4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# []
# 48
# 45
# 0

# %%
print(cs_v2.leads_uptill_grade("3"))
# Out:
# 3

# %%
print(cs_v2.dr_per_lead_for_grade("3"))
# Out:
# grade == :  3  :  16.0 total :  16.0
# grade == :  3  :  1.0 total :  17.0
# 17.0

# %%
print(cs_v2.dr_per_lead_for_grade("4.1"))
# Out:
# grade == :  4.1  :  7.5 total :  7.5
# grade == :  4.1  :  0.5 total :  8.0
# 8.0

# %%
print(cs_v2.dr_per_lead_for_grade("4.2"))
# Out:
# 4.1 : 0.3 total 0.3
# grade == :  4.2  :  4.1 total :  4.3999999999999995
# grade == :  4.2  :  0.4 total :  4.8
# 4.8

# %%
print(cs_v2.dr_per_lead_for_grade("4.3"))
# Out:
# 4.1 : 0.25 total 0.25
# 4.2 : 0.3333333333333333 total 0.5833333333333333
# grade == :  4.3  :  2.9166666666666665 total :  3.5
# grade == :  4.3  :  0.5 total :  4.0
# 4.0

# %% [markdown]
# # State testing

# %%
#two states with same values should have same hash
cs_v2 = Chapter_Stats("BE Chapter", 
                         allocated_leaders = {"3":3, "4.1":3, "4.2":4, "4.3":2},
                         people_gradewise = {"3":3, "4.1":3, "4.2":4, "4.3":6, "4.4":5, "5.1":1, "5.2":2, "MS":27}
                         )

st1=State(cs_v2,Business_Rules())

st2=State(cs_v2,Business_Rules())

print(st1.state_hash())
print(st2.state_hash())
# Out:
# 3696398175509545291
# 3696398175509545291

# %% [markdown]
# # Action Testing

# %%
al = ActionList(Business_Rules().actions)
print(al.actions)
for action in al.actions:
  print(action.print_info())
print(al.list_action_hash)
# Out:
# [<__main__.Action object at 0x7eff0c654cd0>, <__main__.Action object at 0x7eff0c498f10>, <__main__.Action object at 0x7eff0c498c50>]
# reassign -8971151278189542349
# None
# promote_dr 723677642040389671
# None
# hire 4893160418872523351
# None
# [-8971151278189542349, 723677642040389671, 4893160418872523351]

# %% [markdown]
# # Reward Testing

# %%
cs_v2 = Chapter_Stats("BE Chapter", 
                         allocated_leaders = {"3":3, "4.1":3, "4.2":4, "4.3":2},
                         people_gradewise = {"3":3, "4.1":3, "4.2":4, "4.3":6, "4.4":5, "5.1":1, "5.2":2, "MS":27}
                         )

st=State(cs_v2,Business_Rules())

rw = Reward()
act = Action("reassign")

st.print_info()

value = rw.reward_function(st, act)
print("next", 2)
print(value)
new_state = act.perform_action(st)
new_state.print_info()

value = rw.reward_function(new_state, act)
print("next", 3)
print(value)
new_state = act.perform_action(new_state)
new_state.print_info()

value = rw.reward_function(new_state, act)
print("next", 4)
print(value)
new_state = act.perform_action(new_state)
new_state.print_info()

value = rw.reward_function(new_state, act)
print("next", 5)
print(value)
# Out:
# Chapter_Stats_v2
# chapter : BE Chapter
# allocated_leaders : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 2}
# people_gradewise : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 2, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.25 total 0.25
# 4.2 : 0.3333333333333333 total 0.5833333333333333
# grade == :  4.3  :  2.9166666666666665 total :  3.5
# grade == :  4.3  :  0.5 total :  4.0
# num_dr_per_lead **** : 4.0
# drs_per_lead :  4.0
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 3
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 3, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.23076923076923078 total 0.23076923076923078
# 4.2 : 0.3076923076923077 total 0.5384615384615385
# grade == :  4.3  :  2.6923076923076925 total :  3.230769230769231
# grade == :  4.3  :  0.46153846153846156 total :  3.6923076923076925
# num_dr_per_lead **** : 3.6923076923076925
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 3, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.23076923076923078 total 0.23076923076923078
# 4.2 : 0.3076923076923077 total 0.5384615384615385
# grade == :  4.3  :  2.6923076923076925 total :  3.230769230769231
# grade == :  4.3  :  0.46153846153846156 total :  3.6923076923076925
# num_dr_per_lead **** : 3.6923076923076925
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 3, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.23076923076923078 total 0.23076923076923078
# 4.2 : 0.3076923076923077 total 0.5384615384615385
# grade == :  4.3  :  2.6923076923076925 total :  3.230769230769231
# grade == :  4.3  :  0.46153846153846156 total :  3.6923076923076925
# num_dr_per_lead **** : 3.6923076923076925
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 3, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.23076923076923078 total 0.23076923076923078
# 4.2 : 0.3076923076923077 total 0.5384615384615385
# grade == :  4.3  :  2.6923076923076925 total :  3.230769230769231
# grade == :  4.3  :  0.46153846153846156 total :  3.6923076923076925
# num_dr_per_lead **** : 3.6923076923076925
# *****2nd cond***** 3.6923076923076925 **** 5
# next 2
# 100
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 3
# Chapter_Stats_v2
# chapter : BE Chapter
# allocated_leaders : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 3}
# people_gradewise : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 3, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.23076923076923078 total 0.23076923076923078
# 4.2 : 0.3076923076923077 total 0.5384615384615385
# grade == :  4.3  :  2.6923076923076925 total :  3.230769230769231
# grade == :  4.3  :  0.46153846153846156 total :  3.6923076923076925
# num_dr_per_lead **** : 3.6923076923076925
# drs_per_lead :  3.6923076923076925
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 4
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 4, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.21428571428571427 total 0.21428571428571427
# 4.2 : 0.2857142857142857 total 0.5
# grade == :  4.3  :  2.5 total :  3.0
# grade == :  4.3  :  0.42857142857142855 total :  3.4285714285714284
# num_dr_per_lead **** : 3.4285714285714284
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 4, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.21428571428571427 total 0.21428571428571427
# 4.2 : 0.2857142857142857 total 0.5
# grade == :  4.3  :  2.5 total :  3.0
# grade == :  4.3  :  0.42857142857142855 total :  3.4285714285714284
# num_dr_per_lead **** : 3.4285714285714284
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 4, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.21428571428571427 total 0.21428571428571427
# 4.2 : 0.2857142857142857 total 0.5
# grade == :  4.3  :  2.5 total :  3.0
# grade == :  4.3  :  0.42857142857142855 total :  3.4285714285714284
# num_dr_per_lead **** : 3.4285714285714284
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 4, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.21428571428571427 total 0.21428571428571427
# 4.2 : 0.2857142857142857 total 0.5
# grade == :  4.3  :  2.5 total :  3.0
# grade == :  4.3  :  0.42857142857142855 total :  3.4285714285714284
# num_dr_per_lead **** : 3.4285714285714284
# *****2nd cond***** 3.4285714285714284 **** 5
# next 3
# 100
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 4
# Chapter_Stats_v2
# chapter : BE Chapter
# allocated_leaders : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 4}
# people_gradewise : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 4, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.21428571428571427 total 0.21428571428571427
# 4.2 : 0.2857142857142857 total 0.5
# grade == :  4.3  :  2.5 total :  3.0
# grade == :  4.3  :  0.42857142857142855 total :  3.4285714285714284
# num_dr_per_lead **** : 3.4285714285714284
# drs_per_lead :  3.4285714285714284
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 5
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 5, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2 total 0.2
# 4.2 : 0.26666666666666666 total 0.4666666666666667
# grade == :  4.3  :  2.3333333333333335 total :  2.8000000000000003
# grade == :  4.3  :  0.4 total :  3.2
# num_dr_per_lead **** : 3.2
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 5, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2 total 0.2
# 4.2 : 0.26666666666666666 total 0.4666666666666667
# grade == :  4.3  :  2.3333333333333335 total :  2.8000000000000003
# grade == :  4.3  :  0.4 total :  3.2
# num_dr_per_lead **** : 3.2
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 5, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2 total 0.2
# 4.2 : 0.26666666666666666 total 0.4666666666666667
# grade == :  4.3  :  2.3333333333333335 total :  2.8000000000000003
# grade == :  4.3  :  0.4 total :  3.2
# num_dr_per_lead **** : 3.2
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 5, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2 total 0.2
# 4.2 : 0.26666666666666666 total 0.4666666666666667
# grade == :  4.3  :  2.3333333333333335 total :  2.8000000000000003
# grade == :  4.3  :  0.4 total :  3.2
# num_dr_per_lead **** : 3.2
# *****2nd cond***** 3.2 **** 5
# next 4
# 100
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 5
# Chapter_Stats_v2
# chapter : BE Chapter
# allocated_leaders : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 5}
# people_gradewise : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 5, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2 total 0.2
# 4.2 : 0.26666666666666666 total 0.4666666666666667
# grade == :  4.3  :  2.3333333333333335 total :  2.8000000000000003
# grade == :  4.3  :  0.4 total :  3.2
# num_dr_per_lead **** : 3.2
# drs_per_lead :  3.2
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 6
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.1875 total 0.1875
# 4.2 : 0.25 total 0.4375
# grade == :  4.3  :  2.1875 total :  2.625
# grade == :  4.3  :  0.375 total :  3.0
# num_dr_per_lead **** : 3.0
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.1875 total 0.1875
# 4.2 : 0.25 total 0.4375
# grade == :  4.3  :  2.1875 total :  2.625
# grade == :  4.3  :  0.375 total :  3.0
# num_dr_per_lead **** : 3.0
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.1875 total 0.1875
# 4.2 : 0.25 total 0.4375
# grade == :  4.3  :  2.1875 total :  2.625
# grade == :  4.3  :  0.375 total :  3.0
# num_dr_per_lead **** : 3.0
# drs_per_lead **** : {'3': 3, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.1875 total 0.1875
# 4.2 : 0.25 total 0.4375
# grade == :  4.3  :  2.1875 total :  2.625
# grade == :  4.3  :  0.375 total :  3.0
# num_dr_per_lead **** : 3.0
# *****2nd cond***** 3.0 **** 5
# next 5
# 100

# %% [markdown]
# # Trainer Testing

# %%
trainer = Trainer()

trainer.train(False)
# Out:
# reassign -8971151278189542349
# promote_dr 723677642040389671
# hire 4893160418872523351
# preconditioned_episode :
#  {'chapter': 'Analyst', 'allocated_leaders': {'3': 0, '4.1': 1}, 'people_gradewise': {'3': 0, '4.1': 1, '4.2': 6, '4.3': 6, '4.4': 1, '5.1': 0, '5.2': 2, 'MS': 7}}
# episode_number :  0
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  8.0 total :  8.5
# grade == :  4.2  :  3.0 total :  11.5
# num_dr_per_lead **** : 11.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  8.0 total :  8.5
# grade == :  4.2  :  3.0 total :  11.5
# num_dr_per_lead **** : 11.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  8.0 total :  8.5
# grade == :  4.2  :  3.0 total :  11.5
# num_dr_per_lead **** : 11.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  22.0 total :  22.0
# grade == :  4.1  :  1.0 total :  23.0
# num_dr_per_lead **** : 23.0
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  8.0 total :  8.5
# grade == :  4.2  :  3.0 total :  11.5
# num_dr_per_lead **** : 11.5
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  5.333333333333333 total :  5.666666666666666
# grade == :  4.2  :  2.0 total :  7.666666666666666
# num_dr_per_lead **** : 7.666666666666666
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  5.333333333333333 total :  5.666666666666666
# grade == :  4.2  :  2.0 total :  7.666666666666666
# num_dr_per_lead **** : 7.666666666666666
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  5.333333333333333 total :  5.666666666666666
# grade == :  4.2  :  2.0 total :  7.666666666666666
# num_dr_per_lead **** : 7.666666666666666
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  8.0 total :  8.5
# grade == :  4.2  :  3.0 total :  11.5
# num_dr_per_lead **** : 11.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  5.333333333333333 total :  5.666666666666666
# grade == :  4.2  :  2.0 total :  7.666666666666666
# num_dr_per_lead **** : 7.666666666666666
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.25 total 0.25
# grade == :  4.2  :  4.0 total :  4.25
# grade == :  4.2  :  1.5 total :  5.75
# num_dr_per_lead **** : 5.75
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.25 total 0.25
# grade == :  4.2  :  4.0 total :  4.25
# grade == :  4.2  :  1.5 total :  5.75
# num_dr_per_lead **** : 5.75
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.25 total 0.25
# grade == :  4.2  :  4.0 total :  4.25
# grade == :  4.2  :  1.5 total :  5.75
# num_dr_per_lead **** : 5.75
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  5.333333333333333 total :  5.666666666666666
# grade == :  4.2  :  2.0 total :  7.666666666666666
# num_dr_per_lead **** : 7.666666666666666
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.25 total 0.25
# grade == :  4.2  :  4.0 total :  4.25
# grade == :  4.2  :  1.5 total :  5.75
# num_dr_per_lead **** : 5.75
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.2 total 0.2
# grade == :  4.2  :  3.2 total :  3.4000000000000004
# grade == :  4.2  :  1.2 total :  4.6000000000000005
# num_dr_per_lead **** : 4.6000000000000005
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.2 total 0.2
# grade == :  4.2  :  3.2 total :  3.4000000000000004
# grade == :  4.2  :  1.2 total :  4.6000000000000005
# num_dr_per_lead **** : 4.6000000000000005
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.2 total 0.2
# grade == :  4.2  :  3.2 total :  3.4000000000000004
# grade == :  4.2  :  1.2 total :  4.6000000000000005
# num_dr_per_lead **** : 4.6000000000000005
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.2 total 0.2
# grade == :  4.2  :  3.2 total :  3.4000000000000004
# grade == :  4.2  :  1.2 total :  4.6000000000000005
# num_dr_per_lead **** : 4.6000000000000005
# *****2nd cond***** 4.6000000000000005 **** 5
# breaking... terminal state
#
# preconditioned_episode :
#  {'chapter': 'ios', 'allocated_leaders': {'3': 0, '4.1': 0, '4.2': 1}, 'people_gradewise': {'3': 0, '4.1': 0, '4.2': 5, '4.3': 6, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 14}}
# episode_number :  1
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  11.0 total :  11.0
# grade == :  4.2  :  2.5 total :  13.5
# num_dr_per_lead **** : 13.5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  11.0 total :  11.0
# grade == :  4.2  :  2.5 total :  13.5
# num_dr_per_lead **** : 13.5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  11.0 total :  11.0
# grade == :  4.2  :  2.5 total :  13.5
# num_dr_per_lead **** : 13.5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  22.0 total :  22.0
# grade == :  4.2  :  5.0 total :  27.0
# num_dr_per_lead **** : 27.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  11.0 total :  11.0
# grade == :  4.2  :  2.5 total :  13.5
# num_dr_per_lead **** : 13.5
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  7.333333333333333 total :  7.333333333333333
# grade == :  4.2  :  1.6666666666666667 total :  9.0
# num_dr_per_lead **** : 9.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  7.333333333333333 total :  7.333333333333333
# grade == :  4.2  :  1.6666666666666667 total :  9.0
# num_dr_per_lead **** : 9.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  7.333333333333333 total :  7.333333333333333
# grade == :  4.2  :  1.6666666666666667 total :  9.0
# num_dr_per_lead **** : 9.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  11.0 total :  11.0
# grade == :  4.2  :  2.5 total :  13.5
# num_dr_per_lead **** : 13.5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  7.333333333333333 total :  7.333333333333333
# grade == :  4.2  :  1.6666666666666667 total :  9.0
# num_dr_per_lead **** : 9.0
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.5 total :  5.5
# grade == :  4.2  :  1.25 total :  6.75
# num_dr_per_lead **** : 6.75
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.5 total :  5.5
# grade == :  4.2  :  1.25 total :  6.75
# num_dr_per_lead **** : 6.75
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.5 total :  5.5
# grade == :  4.2  :  1.25 total :  6.75
# num_dr_per_lead **** : 6.75
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  7.333333333333333 total :  7.333333333333333
# grade == :  4.2  :  1.6666666666666667 total :  9.0
# num_dr_per_lead **** : 9.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.5 total :  5.5
# grade == :  4.2  :  1.25 total :  6.75
# num_dr_per_lead **** : 6.75
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 5
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.4 total :  4.4
# grade == :  4.2  :  1.0 total :  5.4
# num_dr_per_lead **** : 5.4
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.4 total :  4.4
# grade == :  4.2  :  1.0 total :  5.4
# num_dr_per_lead **** : 5.4
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.4 total :  4.4
# grade == :  4.2  :  1.0 total :  5.4
# num_dr_per_lead **** : 5.4
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.5 total :  5.5
# grade == :  4.2  :  1.25 total :  6.75
# num_dr_per_lead **** : 6.75
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.4 total :  4.4
# grade == :  4.2  :  1.0 total :  5.4
# num_dr_per_lead **** : 5.4
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.8333333333333334 total 0.8333333333333334
# grade == :  4.3  :  2.6666666666666665 total :  3.5
# grade == :  4.3  :  1.0 total :  4.5
# num_dr_per_lead **** : 4.5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.8333333333333334 total 0.8333333333333334
# grade == :  4.3  :  2.6666666666666665 total :  3.5
# grade == :  4.3  :  1.0 total :  4.5
# num_dr_per_lead **** : 4.5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.8333333333333334 total 0.8333333333333334
# grade == :  4.3  :  2.6666666666666665 total :  3.5
# grade == :  4.3  :  1.0 total :  4.5
# num_dr_per_lead **** : 4.5
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 5, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.8333333333333334 total 0.8333333333333334
# grade == :  4.3  :  2.6666666666666665 total :  3.5
# grade == :  4.3  :  1.0 total :  4.5
# num_dr_per_lead **** : 4.5
# *****2nd cond***** 4.5 **** 5
# breaking... terminal state
#
# preconditioned_episode :
#  {'chapter': 'android', 'allocated_leaders': {'3': 0, '4.1': 1}, 'people_gradewise': {'3': 0, '4.1': 0, '4.2': 4, '4.3': 4, '4.4': 4, '5.1': 0, '5.2': 0, 'MS': 9}}
# episode_number :  2
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.5 total :  8.5
# grade == :  4.2  :  2.0 total :  10.5
# num_dr_per_lead **** : 10.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.5 total :  8.5
# grade == :  4.2  :  2.0 total :  10.5
# num_dr_per_lead **** : 10.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.5 total :  8.5
# grade == :  4.2  :  2.0 total :  10.5
# num_dr_per_lead **** : 10.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  21.0 total :  21.0
# grade == :  4.1  :  0.0 total :  21.0
# num_dr_per_lead **** : 21.0
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.5 total :  8.5
# grade == :  4.2  :  2.0 total :  10.5
# num_dr_per_lead **** : 10.5
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.666666666666667 total :  5.666666666666667
# grade == :  4.2  :  1.3333333333333333 total :  7.0
# num_dr_per_lead **** : 7.0
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.666666666666667 total :  5.666666666666667
# grade == :  4.2  :  1.3333333333333333 total :  7.0
# num_dr_per_lead **** : 7.0
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.666666666666667 total :  5.666666666666667
# grade == :  4.2  :  1.3333333333333333 total :  7.0
# num_dr_per_lead **** : 7.0
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.5 total :  8.5
# grade == :  4.2  :  2.0 total :  10.5
# num_dr_per_lead **** : 10.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.666666666666667 total :  5.666666666666667
# grade == :  4.2  :  1.3333333333333333 total :  7.0
# num_dr_per_lead **** : 7.0
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.25 total :  4.25
# grade == :  4.2  :  1.0 total :  5.25
# num_dr_per_lead **** : 5.25
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.25 total :  4.25
# grade == :  4.2  :  1.0 total :  5.25
# num_dr_per_lead **** : 5.25
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.25 total :  4.25
# grade == :  4.2  :  1.0 total :  5.25
# num_dr_per_lead **** : 5.25
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  5.666666666666667 total :  5.666666666666667
# grade == :  4.2  :  1.3333333333333333 total :  7.0
# num_dr_per_lead **** : 7.0
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  4.25 total :  4.25
# grade == :  4.2  :  1.0 total :  5.25
# num_dr_per_lead **** : 5.25
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  3.4 total :  3.4
# grade == :  4.2  :  0.8 total :  4.2
# num_dr_per_lead **** : 4.2
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  3.4 total :  3.4
# grade == :  4.2  :  0.8 total :  4.2
# num_dr_per_lead **** : 4.2
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  3.4 total :  3.4
# grade == :  4.2  :  0.8 total :  4.2
# num_dr_per_lead **** : 4.2
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  3.4 total :  3.4
# grade == :  4.2  :  0.8 total :  4.2
# num_dr_per_lead **** : 4.2
# *****2nd cond***** 4.2 **** 5
# breaking... terminal state
#
# preconditioned_episode :
#  {'chapter': 'be engg', 'allocated_leaders': {'3': 2.5}, 'people_gradewise': {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 6, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}}
# episode_number :  3
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 1
# drs_per_lead **** : {'3': 2.5, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  12.857142857142858 total :  12.857142857142858
# grade == :  4.1  :  0.8571428571428571 total :  13.714285714285715
# num_dr_per_lead **** : 13.714285714285715
# drs_per_lead **** : {'3': 2.5, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  12.857142857142858 total :  12.857142857142858
# grade == :  4.1  :  0.8571428571428571 total :  13.714285714285715
# num_dr_per_lead **** : 13.714285714285715
# drs_per_lead **** : {'3': 2.5, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  12.857142857142858 total :  12.857142857142858
# grade == :  4.1  :  0.8571428571428571 total :  13.714285714285715
# num_dr_per_lead **** : 13.714285714285715
# drs_per_lead **** : {'3': 2.5, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  19.2 total :  19.2
# grade == :  3  :  1.0 total :  20.2
# num_dr_per_lead **** : 20.2
# drs_per_lead **** : {'3': 2.5, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  12.857142857142858 total :  12.857142857142858
# grade == :  4.1  :  0.8571428571428571 total :  13.714285714285715
# num_dr_per_lead **** : 13.714285714285715
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 2
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  10.0 total :  10.0
# grade == :  4.1  :  0.6666666666666666 total :  10.666666666666666
# num_dr_per_lead **** : 10.666666666666666
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  10.0 total :  10.0
# grade == :  4.1  :  0.6666666666666666 total :  10.666666666666666
# num_dr_per_lead **** : 10.666666666666666
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  10.0 total :  10.0
# grade == :  4.1  :  0.6666666666666666 total :  10.666666666666666
# num_dr_per_lead **** : 10.666666666666666
# drs_per_lead **** : {'3': 2.5, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  12.857142857142858 total :  12.857142857142858
# grade == :  4.1  :  0.8571428571428571 total :  13.714285714285715
# num_dr_per_lead **** : 13.714285714285715
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  10.0 total :  10.0
# grade == :  4.1  :  0.6666666666666666 total :  10.666666666666666
# num_dr_per_lead **** : 10.666666666666666
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 3
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 3
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  8.181818181818182 total :  8.181818181818182
# grade == :  4.1  :  0.5454545454545454 total :  8.727272727272727
# num_dr_per_lead **** : 8.727272727272727
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  8.181818181818182 total :  8.181818181818182
# grade == :  4.1  :  0.5454545454545454 total :  8.727272727272727
# num_dr_per_lead **** : 8.727272727272727
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  8.181818181818182 total :  8.181818181818182
# grade == :  4.1  :  0.5454545454545454 total :  8.727272727272727
# num_dr_per_lead **** : 8.727272727272727
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  10.0 total :  10.0
# grade == :  4.1  :  0.6666666666666666 total :  10.666666666666666
# num_dr_per_lead **** : 10.666666666666666
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  8.181818181818182 total :  8.181818181818182
# grade == :  4.1  :  0.5454545454545454 total :  8.727272727272727
# num_dr_per_lead **** : 8.727272727272727
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# grade == :  4.2  :  6.3076923076923075 total :  6.769230769230769
# grade == :  4.2  :  0.6153846153846154 total :  7.384615384615385
# num_dr_per_lead **** : 7.384615384615385
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# grade == :  4.2  :  6.3076923076923075 total :  6.769230769230769
# grade == :  4.2  :  0.6153846153846154 total :  7.384615384615385
# num_dr_per_lead **** : 7.384615384615385
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# grade == :  4.2  :  6.3076923076923075 total :  6.769230769230769
# grade == :  4.2  :  0.6153846153846154 total :  7.384615384615385
# num_dr_per_lead **** : 7.384615384615385
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  8.181818181818182 total :  8.181818181818182
# grade == :  4.1  :  0.5454545454545454 total :  8.727272727272727
# num_dr_per_lead **** : 8.727272727272727
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# grade == :  4.2  :  6.3076923076923075 total :  6.769230769230769
# grade == :  4.2  :  0.6153846153846154 total :  7.384615384615385
# num_dr_per_lead **** : 7.384615384615385
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.4 total 0.4
# grade == :  4.2  :  5.466666666666667 total :  5.866666666666667
# grade == :  4.2  :  0.5333333333333333 total :  6.4
# num_dr_per_lead **** : 6.4
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.4 total 0.4
# grade == :  4.2  :  5.466666666666667 total :  5.866666666666667
# grade == :  4.2  :  0.5333333333333333 total :  6.4
# num_dr_per_lead **** : 6.4
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.4 total 0.4
# grade == :  4.2  :  5.466666666666667 total :  5.866666666666667
# grade == :  4.2  :  0.5333333333333333 total :  6.4
# num_dr_per_lead **** : 6.4
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# grade == :  4.2  :  6.3076923076923075 total :  6.769230769230769
# grade == :  4.2  :  0.6153846153846154 total :  7.384615384615385
# num_dr_per_lead **** : 7.384615384615385
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.4 total 0.4
# grade == :  4.2  :  5.466666666666667 total :  5.866666666666667
# grade == :  4.2  :  0.5333333333333333 total :  6.4
# num_dr_per_lead **** : 6.4
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 3
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.4 total 0.4
# grade == :  4.2  :  5.466666666666667 total :  5.866666666666667
# grade == :  4.2  :  0.5333333333333333 total :  6.4
# num_dr_per_lead **** : 6.4
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 4
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3157894736842105 total 0.3157894736842105
# grade == :  4.2  :  4.315789473684211 total :  4.631578947368421
# grade == :  4.2  :  0.42105263157894735 total :  5.052631578947368
# num_dr_per_lead **** : 5.052631578947368
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3157894736842105 total 0.3157894736842105
# grade == :  4.2  :  4.315789473684211 total :  4.631578947368421
# grade == :  4.2  :  0.42105263157894735 total :  5.052631578947368
# num_dr_per_lead **** : 5.052631578947368
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3157894736842105 total 0.3157894736842105
# grade == :  4.2  :  4.315789473684211 total :  4.631578947368421
# grade == :  4.2  :  0.42105263157894735 total :  5.052631578947368
# num_dr_per_lead **** : 5.052631578947368
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 3, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# grade == :  4.2  :  4.823529411764706 total :  5.1764705882352935
# grade == :  4.2  :  0.47058823529411764 total :  5.647058823529411
# num_dr_per_lead **** : 5.647058823529411
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3157894736842105 total 0.3157894736842105
# grade == :  4.2  :  4.315789473684211 total :  4.631578947368421
# grade == :  4.2  :  0.42105263157894735 total :  5.052631578947368
# num_dr_per_lead **** : 5.052631578947368
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2857142857142857 total 0.2857142857142857
# 4.2 : 0.38095238095238093 total 0.6666666666666666
# grade == :  4.3  :  3.3333333333333335 total :  4.0
# grade == :  4.3  :  0.5714285714285714 total :  4.571428571428571
# num_dr_per_lead **** : 4.571428571428571
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2857142857142857 total 0.2857142857142857
# 4.2 : 0.38095238095238093 total 0.6666666666666666
# grade == :  4.3  :  3.3333333333333335 total :  4.0
# grade == :  4.3  :  0.5714285714285714 total :  4.571428571428571
# num_dr_per_lead **** : 4.571428571428571
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2857142857142857 total 0.2857142857142857
# 4.2 : 0.38095238095238093 total 0.6666666666666666
# grade == :  4.3  :  3.3333333333333335 total :  4.0
# grade == :  4.3  :  0.5714285714285714 total :  4.571428571428571
# num_dr_per_lead **** : 4.571428571428571
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 4, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.2857142857142857 total 0.2857142857142857
# 4.2 : 0.38095238095238093 total 0.6666666666666666
# grade == :  4.3  :  3.3333333333333335 total :  4.0
# grade == :  4.3  :  0.5714285714285714 total :  4.571428571428571
# num_dr_per_lead **** : 4.571428571428571
# *****2nd cond***** 4.571428571428571 **** 5
# breaking... terminal state
#
# preconditioned_episode :
#  {'chapter': 'delivery leads', 'allocated_leaders': {'3': 0, '4.1': 1}, 'people_gradewise': {'3': 0, '4.1': 1, '4.2': 3.5, '4.3': 0.5, '4.4': 0.8, '5.1': 0, '5.2': 0, 'MS': 3}}
# episode_number :  4
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  2.15 total :  2.65
# grade == :  4.2  :  1.75 total :  4.4
# num_dr_per_lead **** : 4.4
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  2.15 total :  2.65
# grade == :  4.2  :  1.75 total :  4.4
# num_dr_per_lead **** : 4.4
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  2.15 total :  2.65
# grade == :  4.2  :  1.75 total :  4.4
# num_dr_per_lead **** : 4.4
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.5 total 0.5
# grade == :  4.2  :  2.15 total :  2.65
# grade == :  4.2  :  1.75 total :  4.4
# num_dr_per_lead **** : 4.4
# *****2nd cond***** 4.4 **** 5
# breaking... terminal state
#
# preconditioned_episode :
#  {'chapter': 'environment', 'allocated_leaders': {'3': 0, '4.1': 0, '4.2': 1}, 'people_gradewise': {'3': 0, '4.1': 0, '4.2': 2, '4.3': 1, '4.4': 1, '5.1': 0, '5.2': 0, 'MS': 2}}
# episode_number :  5
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  2.0 total :  2.0
# grade == :  4.2  :  1.0 total :  3.0
# num_dr_per_lead **** : 3.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  2.0 total :  2.0
# grade == :  4.2  :  1.0 total :  3.0
# num_dr_per_lead **** : 3.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  2.0 total :  2.0
# grade == :  4.2  :  1.0 total :  3.0
# num_dr_per_lead **** : 3.0
# drs_per_lead **** : {'3': 0, '4.1': 0, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  2.0 total :  2.0
# grade == :  4.2  :  1.0 total :  3.0
# num_dr_per_lead **** : 3.0
# *****2nd cond***** 3.0 **** 5
# breaking... terminal state
#
# preconditioned_episode :
#  {'chapter': 'sre', 'allocated_leaders': {'3': 1, '4.1': 1}, 'people_gradewise': {'3': 1, '4.1': 1, '4.2': 1, '4.3': 7, '4.4': 4, '5.1': 0, '5.2': 0, 'MS': 3}}
# episode_number :  6
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  4.666666666666667 total :  5.0
# grade == :  4.2  :  0.3333333333333333 total :  5.333333333333333
# num_dr_per_lead **** : 5.333333333333333
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  4.666666666666667 total :  5.0
# grade == :  4.2  :  0.3333333333333333 total :  5.333333333333333
# num_dr_per_lead **** : 5.333333333333333
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  4.666666666666667 total :  5.0
# grade == :  4.2  :  0.3333333333333333 total :  5.333333333333333
# num_dr_per_lead **** : 5.333333333333333
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  7.5 total :  7.5
# grade == :  4.1  :  0.5 total :  8.0
# num_dr_per_lead **** : 8.0
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.3333333333333333 total 0.3333333333333333
# grade == :  4.2  :  4.666666666666667 total :  5.0
# grade == :  4.2  :  0.3333333333333333 total :  5.333333333333333
# num_dr_per_lead **** : 5.333333333333333
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.25 total 0.25
# 4.2 : 0.25 total 0.5
# grade == :  4.3  :  1.75 total :  2.25
# grade == :  4.3  :  1.75 total :  4.0
# num_dr_per_lead **** : 4.0
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.25 total 0.25
# 4.2 : 0.25 total 0.5
# grade == :  4.3  :  1.75 total :  2.25
# grade == :  4.3  :  1.75 total :  4.0
# num_dr_per_lead **** : 4.0
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.25 total 0.25
# 4.2 : 0.25 total 0.5
# grade == :  4.3  :  1.75 total :  2.25
# grade == :  4.3  :  1.75 total :  4.0
# num_dr_per_lead **** : 4.0
# drs_per_lead **** : {'3': 1, '4.1': 1, '4.2': 1, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.25 total 0.25
# 4.2 : 0.25 total 0.5
# grade == :  4.3  :  1.75 total :  2.25
# grade == :  4.3  :  1.75 total :  4.0
# num_dr_per_lead **** : 4.0
# *****2nd cond***** 4.0 **** 5
# breaking... terminal state
#
# preconditioned_episode :
#  {'chapter': 'testing', 'allocated_leaders': {'3': 0, '4.1': 1}, 'people_gradewise': {'3': 0, '4.1': 0, '4.2': 1.5, '4.3': 3, '4.4': 2, '5.1': 1, '5.2': 0, 'MS': 18}}
# episode_number :  7
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  12.0 total :  12.0
# grade == :  4.2  :  0.75 total :  12.75
# num_dr_per_lead **** : 12.75
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  12.0 total :  12.0
# grade == :  4.2  :  0.75 total :  12.75
# num_dr_per_lead **** : 12.75
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  12.0 total :  12.0
# grade == :  4.2  :  0.75 total :  12.75
# num_dr_per_lead **** : 12.75
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  25.5 total :  25.5
# grade == :  4.1  :  0.0 total :  25.5
# num_dr_per_lead **** : 25.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  12.0 total :  12.0
# grade == :  4.2  :  0.75 total :  12.75
# num_dr_per_lead **** : 12.75
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.2 2
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.0 total :  8.0
# grade == :  4.2  :  0.5 total :  8.5
# num_dr_per_lead **** : 8.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.0 total :  8.0
# grade == :  4.2  :  0.5 total :  8.5
# num_dr_per_lead **** : 8.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.0 total :  8.0
# grade == :  4.2  :  0.5 total :  8.5
# num_dr_per_lead **** : 8.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 1, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  12.0 total :  12.0
# grade == :  4.2  :  0.75 total :  12.75
# num_dr_per_lead **** : 12.75
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.0 total :  8.0
# grade == :  4.2  :  0.5 total :  8.5
# num_dr_per_lead **** : 8.5
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.375 total 0.375
# grade == :  4.3  :  5.25 total :  5.625
# grade == :  4.3  :  0.75 total :  6.375
# num_dr_per_lead **** : 6.375
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.375 total 0.375
# grade == :  4.3  :  5.25 total :  5.625
# grade == :  4.3  :  0.75 total :  6.375
# num_dr_per_lead **** : 6.375
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.375 total 0.375
# grade == :  4.3  :  5.25 total :  5.625
# grade == :  4.3  :  0.75 total :  6.375
# num_dr_per_lead **** : 6.375
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.2
# 4.1 : 0.0 total 0.0
# grade == :  4.2  :  8.0 total :  8.0
# grade == :  4.2  :  0.5 total :  8.5
# num_dr_per_lead **** : 8.5
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.375 total 0.375
# grade == :  4.3  :  5.25 total :  5.625
# grade == :  4.3  :  0.75 total :  6.375
# num_dr_per_lead **** : 6.375
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.3 2
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 2, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.3 total 0.3
# grade == :  4.3  :  4.2 total :  4.5
# grade == :  4.3  :  0.6 total :  5.1
# num_dr_per_lead **** : 5.1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 2, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.3 total 0.3
# grade == :  4.3  :  4.2 total :  4.5
# grade == :  4.3  :  0.6 total :  5.1
# num_dr_per_lead **** : 5.1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 2, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.3 total 0.3
# grade == :  4.3  :  4.2 total :  4.5
# grade == :  4.3  :  0.6 total :  5.1
# num_dr_per_lead **** : 5.1
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 1, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.375 total 0.375
# grade == :  4.3  :  5.25 total :  5.625
# grade == :  4.3  :  0.75 total :  6.375
# num_dr_per_lead **** : 6.375
# drs_per_lead **** : {'3': 0, '4.1': 1, '4.2': 2, '4.3': 2, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.3
# 4.1 : 0.0 total 0.0
# 4.2 : 0.3 total 0.3
# grade == :  4.3  :  4.2 total :  4.5
# grade == :  4.3  :  0.6 total :  5.1
# ...
# drs_per_lead **** : {'3': 22, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.7272727272727275 total :  5.7272727272727275
# grade == :  3  :  1.1363636363636365 total :  6.863636363636364
# num_dr_per_lead **** : 6.863636363636364
# drs_per_lead **** : {'3': 23, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.478260869565218 total :  5.478260869565218
# grade == :  3  :  1.0869565217391304 total :  6.565217391304348
# num_dr_per_lead **** : 6.565217391304348
#
#
# ******reassigned_leader*******
# assign_lead : 3 24
#
#
# ******reassigned_leader*******
# assign_lead : 3 24
# drs_per_lead **** : {'3': 24, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.25 total :  5.25
# grade == :  3  :  1.0416666666666667 total :  6.291666666666667
# num_dr_per_lead **** : 6.291666666666667
# drs_per_lead **** : {'3': 24, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.25 total :  5.25
# grade == :  3  :  1.0416666666666667 total :  6.291666666666667
# num_dr_per_lead **** : 6.291666666666667
# drs_per_lead **** : {'3': 24, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.25 total :  5.25
# grade == :  3  :  1.0416666666666667 total :  6.291666666666667
# num_dr_per_lead **** : 6.291666666666667
# drs_per_lead **** : {'3': 23, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.478260869565218 total :  5.478260869565218
# grade == :  3  :  1.0869565217391304 total :  6.565217391304348
# num_dr_per_lead **** : 6.565217391304348
# drs_per_lead **** : {'3': 24, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.25 total :  5.25
# grade == :  3  :  1.0416666666666667 total :  6.291666666666667
# num_dr_per_lead **** : 6.291666666666667
#
#
# ******reassigned_leader*******
# assign_lead : 3 25
#
#
# ******reassigned_leader*******
# assign_lead : 3 25
# drs_per_lead **** : {'3': 25, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.04 total :  5.04
# grade == :  3  :  1.0 total :  6.04
# num_dr_per_lead **** : 6.04
# drs_per_lead **** : {'3': 25, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.04 total :  5.04
# grade == :  3  :  1.0 total :  6.04
# num_dr_per_lead **** : 6.04
# drs_per_lead **** : {'3': 25, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.04 total :  5.04
# grade == :  3  :  1.0 total :  6.04
# num_dr_per_lead **** : 6.04
# drs_per_lead **** : {'3': 24, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.25 total :  5.25
# grade == :  3  :  1.0416666666666667 total :  6.291666666666667
# num_dr_per_lead **** : 6.291666666666667
# drs_per_lead **** : {'3': 25, '4.1': 0, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 3
# grade == :  3  :  5.04 total :  5.04
# grade == :  3  :  1.0 total :  6.04
# num_dr_per_lead **** : 6.04
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 1
# drs_per_lead **** : {'3': 25, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  3.9615384615384617 total :  3.9615384615384617
# grade == :  4.1  :  0.8846153846153846 total :  4.846153846153847
# num_dr_per_lead **** : 4.846153846153847
# drs_per_lead **** : {'3': 25, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  3.9615384615384617 total :  3.9615384615384617
# grade == :  4.1  :  0.8846153846153846 total :  4.846153846153847
# num_dr_per_lead **** : 4.846153846153847
# drs_per_lead **** : {'3': 25, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  3.9615384615384617 total :  3.9615384615384617
# grade == :  4.1  :  0.8846153846153846 total :  4.846153846153847
# num_dr_per_lead **** : 4.846153846153847
# drs_per_lead **** : {'3': 25, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  3.9615384615384617 total :  3.9615384615384617
# grade == :  4.1  :  0.8846153846153846 total :  4.846153846153847
# num_dr_per_lead **** : 4.846153846153847
# *****2nd cond***** 4.846153846153847 **** 5
# breaking... terminal state
#
# simulated episode data :
# Chapter_Stats_v2
# chapter : chapter
# allocated_leaders : {'3': 21, '4.1': 18, '4.2': 0, '4.3': 12, '4.4': 2}
# people_gradewise : {'3': 40, '4.1': 25, '4.2': 1, '4.3': 27, '4.4': 42, '5.1': 7, '5.2': 4, 'MS': 29}
# drs_per_lead **** : {'3': 21, '4.1': 18, '4.2': 0, '4.3': 12, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.4716981132075472 total 0.4716981132075472
# 4.2 : 0.018867924528301886 total 0.49056603773584906
# 4.3 : 0.5094339622641509 total 1.0
# grade == :  4.4  :  0.7547169811320755 total :  1.7547169811320755
# grade == :  4.4  :  0.7924528301886793 total :  2.547169811320755
# num_dr_per_lead **** : 2.547169811320755
# drs_per_lead :  2.547169811320755
# episode_number :  13
#
#
# ******reassigned_leader*******
# assign_lead : 3 22
#
#
# ******reassigned_leader*******
# assign_lead : 3 22
# drs_per_lead **** : {'3': 22, '4.1': 18, '4.2': 0, '4.3': 12, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46296296296296297 total 0.46296296296296297
# 4.2 : 0.018518518518518517 total 0.4814814814814815
# 4.3 : 0.5 total 0.9814814814814815
# grade == :  4.4  :  0.7407407407407407 total :  1.7222222222222223
# grade == :  4.4  :  0.7777777777777778 total :  2.5
# num_dr_per_lead **** : 2.5
# drs_per_lead **** : {'3': 22, '4.1': 18, '4.2': 0, '4.3': 12, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46296296296296297 total 0.46296296296296297
# 4.2 : 0.018518518518518517 total 0.4814814814814815
# 4.3 : 0.5 total 0.9814814814814815
# grade == :  4.4  :  0.7407407407407407 total :  1.7222222222222223
# grade == :  4.4  :  0.7777777777777778 total :  2.5
# num_dr_per_lead **** : 2.5
# drs_per_lead **** : {'3': 22, '4.1': 18, '4.2': 0, '4.3': 12, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46296296296296297 total 0.46296296296296297
# 4.2 : 0.018518518518518517 total 0.4814814814814815
# 4.3 : 0.5 total 0.9814814814814815
# grade == :  4.4  :  0.7407407407407407 total :  1.7222222222222223
# grade == :  4.4  :  0.7777777777777778 total :  2.5
# num_dr_per_lead **** : 2.5
# drs_per_lead **** : {'3': 22, '4.1': 18, '4.2': 0, '4.3': 12, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46296296296296297 total 0.46296296296296297
# 4.2 : 0.018518518518518517 total 0.4814814814814815
# 4.3 : 0.5 total 0.9814814814814815
# grade == :  4.4  :  0.7407407407407407 total :  1.7222222222222223
# grade == :  4.4  :  0.7777777777777778 total :  2.5
# num_dr_per_lead **** : 2.5
# *****2nd cond***** 2.5 **** 5
# breaking... terminal state
#
# simulated episode data :
# Chapter_Stats_v2
# chapter : chapter
# allocated_leaders : {'3': 14, '4.1': 22}
# people_gradewise : {'3': 27, '4.1': 25, '4.2': 35, '4.3': 37, '4.4': 23, '5.1': 19, '5.2': 24, 'MS': 41}
# drs_per_lead **** : {'3': 14, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.972222222222222 total :  4.972222222222222
# grade == :  4.1  :  0.6944444444444444 total :  5.666666666666667
# num_dr_per_lead **** : 5.666666666666667
# drs_per_lead :  5.666666666666667
# episode_number :  14
#
#
# ******reassigned_leader*******
# assign_lead : 3 15
#
#
# ******reassigned_leader*******
# assign_lead : 3 15
# drs_per_lead **** : {'3': 15, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.837837837837838 total :  4.837837837837838
# grade == :  4.1  :  0.6756756756756757 total :  5.513513513513513
# num_dr_per_lead **** : 5.513513513513513
# drs_per_lead **** : {'3': 15, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.837837837837838 total :  4.837837837837838
# grade == :  4.1  :  0.6756756756756757 total :  5.513513513513513
# num_dr_per_lead **** : 5.513513513513513
# drs_per_lead **** : {'3': 15, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.837837837837838 total :  4.837837837837838
# grade == :  4.1  :  0.6756756756756757 total :  5.513513513513513
# num_dr_per_lead **** : 5.513513513513513
# drs_per_lead **** : {'3': 14, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.972222222222222 total :  4.972222222222222
# grade == :  4.1  :  0.6944444444444444 total :  5.666666666666667
# num_dr_per_lead **** : 5.666666666666667
# drs_per_lead **** : {'3': 15, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.837837837837838 total :  4.837837837837838
# grade == :  4.1  :  0.6756756756756757 total :  5.513513513513513
# num_dr_per_lead **** : 5.513513513513513
#
#
# ******reassigned_leader*******
# assign_lead : 3 16
#
#
# ******reassigned_leader*******
# assign_lead : 3 16
# drs_per_lead **** : {'3': 16, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.7105263157894735 total :  4.7105263157894735
# grade == :  4.1  :  0.6578947368421053 total :  5.368421052631579
# num_dr_per_lead **** : 5.368421052631579
# drs_per_lead **** : {'3': 16, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.7105263157894735 total :  4.7105263157894735
# grade == :  4.1  :  0.6578947368421053 total :  5.368421052631579
# num_dr_per_lead **** : 5.368421052631579
# drs_per_lead **** : {'3': 16, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.7105263157894735 total :  4.7105263157894735
# grade == :  4.1  :  0.6578947368421053 total :  5.368421052631579
# num_dr_per_lead **** : 5.368421052631579
# drs_per_lead **** : {'3': 15, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.837837837837838 total :  4.837837837837838
# grade == :  4.1  :  0.6756756756756757 total :  5.513513513513513
# num_dr_per_lead **** : 5.513513513513513
# drs_per_lead **** : {'3': 16, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.7105263157894735 total :  4.7105263157894735
# grade == :  4.1  :  0.6578947368421053 total :  5.368421052631579
# num_dr_per_lead **** : 5.368421052631579
#
#
# ******reassigned_leader*******
# assign_lead : 3 17
#
#
# ******reassigned_leader*******
# assign_lead : 3 17
# drs_per_lead **** : {'3': 17, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.589743589743589 total :  4.589743589743589
# grade == :  4.1  :  0.6410256410256411 total :  5.230769230769231
# num_dr_per_lead **** : 5.230769230769231
# drs_per_lead **** : {'3': 17, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.589743589743589 total :  4.589743589743589
# grade == :  4.1  :  0.6410256410256411 total :  5.230769230769231
# num_dr_per_lead **** : 5.230769230769231
# drs_per_lead **** : {'3': 17, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.589743589743589 total :  4.589743589743589
# grade == :  4.1  :  0.6410256410256411 total :  5.230769230769231
# num_dr_per_lead **** : 5.230769230769231
# drs_per_lead **** : {'3': 16, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.7105263157894735 total :  4.7105263157894735
# grade == :  4.1  :  0.6578947368421053 total :  5.368421052631579
# num_dr_per_lead **** : 5.368421052631579
# drs_per_lead **** : {'3': 17, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.589743589743589 total :  4.589743589743589
# grade == :  4.1  :  0.6410256410256411 total :  5.230769230769231
# num_dr_per_lead **** : 5.230769230769231
#
#
# ******reassigned_leader*******
# assign_lead : 3 18
#
#
# ******reassigned_leader*******
# assign_lead : 3 18
# drs_per_lead **** : {'3': 18, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.475 total :  4.475
# grade == :  4.1  :  0.625 total :  5.1
# num_dr_per_lead **** : 5.1
# drs_per_lead **** : {'3': 18, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.475 total :  4.475
# grade == :  4.1  :  0.625 total :  5.1
# num_dr_per_lead **** : 5.1
# drs_per_lead **** : {'3': 18, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.475 total :  4.475
# grade == :  4.1  :  0.625 total :  5.1
# num_dr_per_lead **** : 5.1
# drs_per_lead **** : {'3': 17, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.589743589743589 total :  4.589743589743589
# grade == :  4.1  :  0.6410256410256411 total :  5.230769230769231
# num_dr_per_lead **** : 5.230769230769231
# drs_per_lead **** : {'3': 18, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.475 total :  4.475
# grade == :  4.1  :  0.625 total :  5.1
# num_dr_per_lead **** : 5.1
#
#
# ******reassigned_leader*******
# assign_lead : 3 19
#
#
# ******reassigned_leader*******
# assign_lead : 3 19
# drs_per_lead **** : {'3': 19, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.365853658536586 total :  4.365853658536586
# grade == :  4.1  :  0.6097560975609756 total :  4.975609756097561
# num_dr_per_lead **** : 4.975609756097561
# drs_per_lead **** : {'3': 19, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.365853658536586 total :  4.365853658536586
# grade == :  4.1  :  0.6097560975609756 total :  4.975609756097561
# num_dr_per_lead **** : 4.975609756097561
# drs_per_lead **** : {'3': 19, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.365853658536586 total :  4.365853658536586
# grade == :  4.1  :  0.6097560975609756 total :  4.975609756097561
# num_dr_per_lead **** : 4.975609756097561
# drs_per_lead **** : {'3': 19, '4.1': 22, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  4.365853658536586 total :  4.365853658536586
# grade == :  4.1  :  0.6097560975609756 total :  4.975609756097561
# num_dr_per_lead **** : 4.975609756097561
# *****2nd cond***** 4.975609756097561 **** 5
# breaking... terminal state

# %%
trainer.q_table.print_info()
# Out:
# Q_table
# {'5454514358291106447 -8971151278189542349': 10.35, '5454514358291106447 723677642040389671': 0, '5454514358291106447 4893160418872523351': 0, '-867430825474681255 -8971151278189542349': 3.4500000000000006, '-867430825474681255 723677642040389671': 0, '-867430825474681255 4893160418872523351': 0, '3832199634541850234 -8971151278189542349': 1.7249999999999994, '3832199634541850234 723677642040389671': 0, '3832199634541850234 4893160418872523351': 0, '8245291951820851567 -8971151278189542349': 0, '8245291951820851567 723677642040389671': 0, '8245291951820851567 4893160418872523351': 0, '6725350205005147841 -8971151278189542349': 12.15, '6725350205005147841 723677642040389671': 0, '6725350205005147841 4893160418872523351': 0, '-8504482755567114734 -8971151278189542349': 4.05, '-8504482755567114734 723677642040389671': 0, '-8504482755567114734 4893160418872523351': 0, '5763604294278183851 -8971151278189542349': 2.025, '5763604294278183851 723677642040389671': 0, '5763604294278183851 4893160418872523351': 0, '-6785001697910080396 -8971151278189542349': 1.2149999999999996, '-6785001697910080396 723677642040389671': 0, '-6785001697910080396 4893160418872523351': 0, '-5791896772195128011 -8971151278189542349': 0, '-5791896772195128011 723677642040389671': 0, '-5791896772195128011 4893160418872523351': 0, '-3611009097411790537 -8971151278189542349': 9.450000000000001, '-3611009097411790537 723677642040389671': 0, '-3611009097411790537 4893160418872523351': 0, '-1487715717639193167 -8971151278189542349': 3.15, '-1487715717639193167 723677642040389671': 0, '-1487715717639193167 4893160418872523351': 0, '-565103514257482242 -8971151278189542349': 1.575, '-565103514257482242 723677642040389671': 0, '-565103514257482242 4893160418872523351': 0, '-6271694390178801065 -8971151278189542349': 0, '-6271694390178801065 723677642040389671': 0, '-6271694390178801065 4893160418872523351': 0, '156267746214590339 -8971151278189542349': 5.837142857142855, '156267746214590339 723677642040389671': 0, '156267746214590339 4893160418872523351': 0, '-7005837628308593584 -8971151278189542349': 2.742857142857144, '-7005837628308593584 723677642040389671': 0, '-7005837628308593584 4893160418872523351': 0, '4254309132208170815 -8971151278189542349': 1.7454545454545456, '4254309132208170815 723677642040389671': 0, '4254309132208170815 4893160418872523351': 0, '906030407634835430 -8971151278189542349': 1.2083916083916075, '906030407634835430 723677642040389671': 0, '906030407634835430 4893160418872523351': 0, '7415187463885044012 -8971151278189542349': 0.8861538461538462, '7415187463885044012 723677642040389671': 0, '7415187463885044012 4893160418872523351': 0, '-3951537011974869857 -8971151278189542349': 0.6776470588235303, '-3951537011974869857 723677642040389671': 0, '-3951537011974869857 4893160418872523351': 0, '2976443750475886854 -8971151278189542349': 0.5349845201238388, '2976443750475886854 723677642040389671': 0, '2976443750475886854 4893160418872523351': 0.0, '-6624608652265271967 -8971151278189542349': 0, '-6624608652265271967 723677642040389671': 0, '-6624608652265271967 4893160418872523351': 0, '-2562161236779383385 -8971151278189542349': 0, '-2562161236779383385 723677642040389671': 0, '-2562161236779383385 4893160418872523351': 0, '-9160926873753922071 -8971151278189542349': 0, '-9160926873753922071 723677642040389671': 0, '-9160926873753922071 4893160418872523351': 0, '-4301335540144829859 -8971151278189542349': 2.4000000000000004, '-4301335540144829859 723677642040389671': 0, '-4301335540144829859 4893160418872523351': 0, '4455360789187664285 -8971151278189542349': 0, '4455360789187664285 723677642040389671': 0, '4455360789187664285 4893160418872523351': 0, '8801125822033056115 -8971151278189542349': 11.475, '8801125822033056115 723677642040389671': 0, '8801125822033056115 4893160418872523351': 0, '7986856165459110061 -8971151278189542349': 3.825, '7986856165459110061 723677642040389671': 0, '7986856165459110061 4893160418872523351': 0, '79441129 ...

# %% [markdown]
# # Episode Testing - Inference

# %%
episode = Episode(8)
trainer.get_shortest_path(episode.state)
# Out:
# preconditioned_episode :
#  {'chapter': 'reassign wont work', 'allocated_leaders': {'3': 2.5, '4.1': 1}, 'people_gradewise': {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}}
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 2
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  7.777777777777778 total :  7.777777777777778
# grade == :  4.1  :  0.6666666666666666 total :  8.444444444444445
# num_dr_per_lead **** : 8.444444444444445
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  7.777777777777778 total :  7.777777777777778
# grade == :  4.1  :  0.6666666666666666 total :  8.444444444444445
# num_dr_per_lead **** : 8.444444444444445
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  7.777777777777778 total :  7.777777777777778
# grade == :  4.1  :  0.6666666666666666 total :  8.444444444444445
# num_dr_per_lead **** : 8.444444444444445
# drs_per_lead **** : {'3': 2.5, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  10.0 total :  10.0
# grade == :  4.1  :  0.8571428571428571 total :  10.857142857142858
# num_dr_per_lead **** : 10.857142857142858
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  7.777777777777778 total :  7.777777777777778
# grade == :  4.1  :  0.6666666666666666 total :  8.444444444444445
# num_dr_per_lead **** : 8.444444444444445
# reward : 2.412698412698413
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 3
#
#
# ******reassigned_leader*******
# assign_lead : 4.1 3
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  6.363636363636363 total :  6.363636363636363
# grade == :  4.1  :  0.5454545454545454 total :  6.909090909090908
# num_dr_per_lead **** : 6.909090909090908
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  6.363636363636363 total :  6.363636363636363
# grade == :  4.1  :  0.5454545454545454 total :  6.909090909090908
# num_dr_per_lead **** : 6.909090909090908
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  6.363636363636363 total :  6.363636363636363
# grade == :  4.1  :  0.5454545454545454 total :  6.909090909090908
# num_dr_per_lead **** : 6.909090909090908
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  7.777777777777778 total :  7.777777777777778
# grade == :  4.1  :  0.6666666666666666 total :  8.444444444444445
# num_dr_per_lead **** : 8.444444444444445
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  6.363636363636363 total :  6.363636363636363
# grade == :  4.1  :  0.5454545454545454 total :  6.909090909090908
# num_dr_per_lead **** : 6.909090909090908
# reward : 1.5353535353535364
#
#
# ******reassigned_leader*******
# assign_lead : 4.4 1
#
#
# ******reassigned_leader*******
# assign_lead : 4.4 1
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 1, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# 4.2 : 0.0 total 0.46153846153846156
# 4.3 : 0.0 total 0.46153846153846156
# grade == :  4.4  :  4.615384615384615 total :  5.076923076923077
# grade == :  4.4  :  0.7692307692307693 total :  5.846153846153846
# num_dr_per_lead **** : 5.846153846153846
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 1, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# 4.2 : 0.0 total 0.46153846153846156
# 4.3 : 0.0 total 0.46153846153846156
# grade == :  4.4  :  4.615384615384615 total :  5.076923076923077
# grade == :  4.4  :  0.7692307692307693 total :  5.846153846153846
# num_dr_per_lead **** : 5.846153846153846
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 1, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# 4.2 : 0.0 total 0.46153846153846156
# 4.3 : 0.0 total 0.46153846153846156
# grade == :  4.4  :  4.615384615384615 total :  5.076923076923077
# grade == :  4.4  :  0.7692307692307693 total :  5.846153846153846
# num_dr_per_lead **** : 5.846153846153846
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  6.363636363636363 total :  6.363636363636363
# grade == :  4.1  :  0.5454545454545454 total :  6.909090909090908
# num_dr_per_lead **** : 6.909090909090908
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 1, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# 4.2 : 0.0 total 0.46153846153846156
# 4.3 : 0.0 total 0.46153846153846156
# grade == :  4.4  :  4.615384615384615 total :  5.076923076923077
# grade == :  4.4  :  0.7692307692307693 total :  5.846153846153846
# num_dr_per_lead **** : 5.846153846153846
# reward : 1.0629370629370625
#
#
# ******reassigned_leader*******
# assign_lead : 4.4 2
#
#
# ******reassigned_leader*******
# assign_lead : 4.4 2
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.4 total 0.4
# 4.2 : 0.0 total 0.4
# 4.3 : 0.0 total 0.4
# grade == :  4.4  :  4.0 total :  4.4
# grade == :  4.4  :  0.6666666666666666 total :  5.066666666666667
# num_dr_per_lead **** : 5.066666666666667
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.4 total 0.4
# 4.2 : 0.0 total 0.4
# 4.3 : 0.0 total 0.4
# grade == :  4.4  :  4.0 total :  4.4
# grade == :  4.4  :  0.6666666666666666 total :  5.066666666666667
# num_dr_per_lead **** : 5.066666666666667
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.4 total 0.4
# 4.2 : 0.0 total 0.4
# 4.3 : 0.0 total 0.4
# grade == :  4.4  :  4.0 total :  4.4
# grade == :  4.4  :  0.6666666666666666 total :  5.066666666666667
# num_dr_per_lead **** : 5.066666666666667
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 1, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# 4.2 : 0.0 total 0.46153846153846156
# 4.3 : 0.0 total 0.46153846153846156
# grade == :  4.4  :  4.615384615384615 total :  5.076923076923077
# grade == :  4.4  :  0.7692307692307693 total :  5.846153846153846
# num_dr_per_lead **** : 5.846153846153846
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.4 total 0.4
# 4.2 : 0.0 total 0.4
# 4.3 : 0.0 total 0.4
# grade == :  4.4  :  4.0 total :  4.4
# grade == :  4.4  :  0.6666666666666666 total :  5.066666666666667
# num_dr_per_lead **** : 5.066666666666667
# reward : 0.7794871794871785
#
#
# ******reassigned_leader*******
# assign_lead : 4.4 3
#
#
# ******reassigned_leader*******
# assign_lead : 4.4 3
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 3, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# 4.2 : 0.0 total 0.35294117647058826
# 4.3 : 0.0 total 0.35294117647058826
# grade == :  4.4  :  3.5294117647058822 total :  3.8823529411764706
# grade == :  4.4  :  0.5882352941176471 total :  4.470588235294118
# num_dr_per_lead **** : 4.470588235294118
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 3, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# 4.2 : 0.0 total 0.35294117647058826
# 4.3 : 0.0 total 0.35294117647058826
# grade == :  4.4  :  3.5294117647058822 total :  3.8823529411764706
# grade == :  4.4  :  0.5882352941176471 total :  4.470588235294118
# num_dr_per_lead **** : 4.470588235294118
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 3, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# 4.2 : 0.0 total 0.35294117647058826
# 4.3 : 0.0 total 0.35294117647058826
# grade == :  4.4  :  3.5294117647058822 total :  3.8823529411764706
# grade == :  4.4  :  0.5882352941176471 total :  4.470588235294118
# num_dr_per_lead **** : 4.470588235294118
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 3, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# 4.2 : 0.0 total 0.35294117647058826
# 4.3 : 0.0 total 0.35294117647058826
# grade == :  4.4  :  3.5294117647058822 total :  3.8823529411764706
# grade == :  4.4  :  0.5882352941176471 total :  4.470588235294118
# num_dr_per_lead **** : 4.470588235294118
# *****2nd cond***** 4.470588235294118 **** 5
# reward : 100
# Chapter_Stats_v2
# chapter : reassign wont work
# allocated_leaders : {'3': 2.5, '4.1': 1}
# people_gradewise : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 2.5, '4.1': 1, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  10.0 total :  10.0
# grade == :  4.1  :  0.8571428571428571 total :  10.857142857142858
# num_dr_per_lead **** : 10.857142857142858
# drs_per_lead :  10.857142857142858
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
# Chapter_Stats_v2
# chapter : reassign wont work
# allocated_leaders : {'3': 2.5, '4.1': 2}
# people_gradewise : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 2.5, '4.1': 2, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  7.777777777777778 total :  7.777777777777778
# grade == :  4.1  :  0.6666666666666666 total :  8.444444444444445
# num_dr_per_lead **** : 8.444444444444445
# drs_per_lead :  8.444444444444445
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
# Chapter_Stats_v2
# chapter : reassign wont work
# allocated_leaders : {'3': 2.5, '4.1': 3}
# people_gradewise : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 0, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.1
# grade == :  4.1  :  6.363636363636363 total :  6.363636363636363
# grade == :  4.1  :  0.5454545454545454 total :  6.909090909090908
# num_dr_per_lead **** : 6.909090909090908
# drs_per_lead :  6.909090909090908
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
# Chapter_Stats_v2
# chapter : reassign wont work
# allocated_leaders : {'3': 2.5, '4.1': 3, '4.4': 1}
# people_gradewise : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 1, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.46153846153846156 total 0.46153846153846156
# 4.2 : 0.0 total 0.46153846153846156
# 4.3 : 0.0 total 0.46153846153846156
# grade == :  4.4  :  4.615384615384615 total :  5.076923076923077
# grade == :  4.4  :  0.7692307692307693 total :  5.846153846153846
# num_dr_per_lead **** : 5.846153846153846
# drs_per_lead :  5.846153846153846
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
# Chapter_Stats_v2
# chapter : reassign wont work
# allocated_leaders : {'3': 2.5, '4.1': 3, '4.4': 2}
# people_gradewise : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 2, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.4 total 0.4
# 4.2 : 0.0 total 0.4
# 4.3 : 0.0 total 0.4
# grade == :  4.4  :  4.0 total :  4.4
# grade == :  4.4  :  0.6666666666666666 total :  5.066666666666667
# num_dr_per_lead **** : 5.066666666666667
# drs_per_lead :  5.066666666666667
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
# Chapter_Stats_v2
# chapter : reassign wont work
# allocated_leaders : {'3': 2.5, '4.1': 3, '4.4': 3}
# people_gradewise : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 5, '5.1': 1, '5.2': 2, 'MS': 27}
# drs_per_lead **** : {'3': 2.5, '4.1': 3, '4.2': 0, '4.3': 0, '4.4': 3, '5.1': 0, '5.2': 0, 'MS': 0}
# max_grade_of_allocated_leader **** : 4.4
# 4.1 : 0.35294117647058826 total 0.35294117647058826
# 4.2 : 0.0 total 0.35294117647058826
# 4.3 : 0.0 total 0.35294117647058826
# grade == :  4.4  :  3.5294117647058822 total :  3.8823529411764706
# grade == :  4.4  :  0.5882352941176471 total :  4.470588235294118
# num_dr_per_lead **** : 4.470588235294118
# drs_per_lead :  4.470588235294118
# Business Rules
# 5
# ['reassign', 'promote_dr', 'hire']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2', 'MS']
# ['3', '4.1', '4.2', '4.3', '4.4', '5.1', '5.2']
